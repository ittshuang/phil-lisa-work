# %%
import pandas as pd 
import os
import numpy as np

COMPSEG_FILE = r'data\firm_info\compustats_segment_00_21.dta'
HH_FILE = r"data\hh_dataset\publicfirm_site.dta"

industry_map = {
    range(1, 10): "AG-M-C",
    range(10, 15): "AG-M-C",
    range(15, 18): "AG-M-C",
    range(20, 40): "MANUF",
    range(40, 50): "TR-UTL",
    range(50, 52): "WHL-RT",
    range(52, 60): "WHL-RT",
    range(60, 68): "F-I-RE",
    range(70, 90): "SVCS",
    range(91, 100): "GOVT"
}

def filter_high_priority(df):
    min_priority = df.groupby(['gvkey', 'fyear'])['priority'].transform('min')
    return df[df['priority'] == min_priority]


def map_industry(code):
    for code_range, abbr in industry_map.items():
        if code in code_range:
            return abbr
    return None

# %%
cd C:\Users\ttshuang\Dropbox\Phil\phil-lisa-work
# Out:
# C:\Users\ttshuang\Dropbox\Phil\phil-lisa-work

# %%
# read data and keep relevant columns
comp_seg = pd.read_stata(COMPSEG_FILE)[
    ['gvkey','fyear','total_sales','sid','stype','snms','emps','seg_sale','SICS1']
    ].sort_values(['gvkey','fyear']).reset_index(drop=True)

# Only keep year 2001 to 2009 as the HH data is from 2001 to 2009
comp_seg = comp_seg[(comp_seg['fyear']<=2009) & (comp_seg['fyear']>=2001)].reset_index(drop=True)
# only keep one stype based on the priority
priority = {'GEOSEG': 2, 'BUSSEG': 2, 'OPSEG': 3, 'STSEG': 1}
comp_seg['priority'] = comp_seg['stype'].map(priority)
comp_seg = filter_high_priority(comp_seg)
comp_seg = comp_seg.drop(columns=['priority'])

# %%
comp_seg.head(10)
# Out:
#     gvkey   fyear  total_sales   sid   stype  \
# 0  001004  2001.0      638.721  12.0  BUSSEG
# 1  001004  2001.0      638.721  13.0  BUSSEG
# 2  001004  2001.0      638.721  10.0  BUSSEG
# 3  001004  2001.0      638.721  14.0  BUSSEG
# 4  001004  2002.0      606.337  16.0  BUSSEG
# 5  001004  2002.0      606.337  15.0  BUSSEG
# 6  001004  2002.0      606.337  17.0  BUSSEG
# 7  001004  2002.0      606.337  18.0  BUSSEG
# 8  001004  2003.0      651.958  15.0  BUSSEG
# 9  001004  2003.0      651.958  17.0  BUSSEG
#
#                                     snms  emps  seg_sale SICS1
# 0        Inventory and Logistic Services   NaN   258.067  5088
# 1       Maintenance, Repair and Overhaul   NaN   216.727  4581
# 2                          Manufacturing   NaN    99.558  3559
# 3  Aircraft and Engine Sales and Leasing   NaN    64.369  5088
# 4                 Structures and Systems   NaN   130.628  3559
# 5                 Aviation Supply  Chain   NaN   358.412  5088
# 6             Aircraft Sales and Leasing   NaN    17.387  5088
# 7       Maintenance, Repair and Overhaul   NaN    93.415  4581
# 8                 Aviation Supply  Chain   NaN   349.527  5088
# 9             Aircraft Sales and Leasing   NaN    24.969  5088

# %%
# read processed hh_site data
hh_site = pd.read_stata(HH_FILE)[
    ['gvkey','year','corpid','siteid','emple','reven','avg_reven']
    ].sort_values(['gvkey','year']).reset_index(drop=True)
hh_site.head(10)
# Out:
#     gvkey    year  corpid     siteid  emple  reven  avg_reven
# 0  001004  2001.0    5689  110023187     99     14   0.141414
# 1  001004  2001.0    5689  107007880    104     18   0.173077
# 2  001004  2001.0    5689  114001316    400    344   0.860000
# 3  001004  2001.0    5689  123000762    150     70   0.466667
# 4  001004  2001.0    5689  110018783    290     60   0.206897
# 5  001004  2002.0    5689  114001316    400    344   0.860000
# 6  001004  2002.0    5689  123000762     90     42   0.466667
# 7  001004  2002.0    5689  110023187    130     18   0.138462
# 8  001004  2002.0    5689  107007880     60     11   0.183333
# 9  001004  2002.0    5689  110018783    200     42   0.210000

# %%
# No industry for this processed industry data - add 2004 data from the raw data
# start from raw hh 2004 data - add sic code 
raw_2004 = pd.read_csv(r'data\hh_dataset\USA_2004\Hist2004_SITEDESC.txt', delimiter="\t", encoding='latin1')
cols = ['SITEID','CORPHDQ','SICCODE','SICGRP','ENTREVENUE']
raw_2004 = raw_2004[cols]
raw_2004.columns = ['siteid','corphdq','siccode','SICGRP','entrevenue']

# only look at 2004 data
hh_site_2004 = hh_site[hh_site['year']==2004]
# link with hh_site 2004 data
hh_site_2004 = hh_site_2004.merge(raw_2004, on='siteid', how='left' )

# map ind group for compustats data
comp_seg_2004 = comp_seg[comp_seg['fyear']==2004]
comp_seg_2004['sic2d'] = comp_seg_2004['SICS1'].astype(str).str[:2].astype(int) 
comp_seg_2004['SICGRP'] = comp_seg_2004['sic2d'].apply(map_industry)
# Out:
# C:\Users\ttshuang\AppData\Local\Temp\ipykernel_22684\2869924936.py:3: DtypeWarning: Columns (6,29,35,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_2004 = pd.read_csv(r'data\hh_dataset\USA_2004\Hist2004_SITEDESC.txt', delimiter="\t", encoding='latin1')
# C:\Users\ttshuang\AppData\Local\Temp\ipykernel_22684\2869924936.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_seg_2004['sic2d'] = comp_seg_2004['SICS1'].astype(str).str[:2].astype(int)
# C:\Users\ttshuang\AppData\Local\Temp\ipykernel_22684\2869924936.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_seg_2004['SICGRP'] = comp_seg_2004['sic2d'].apply(map_industry)

# %%
comp_seg_2004_geo = comp_seg_2004[comp_seg_2004['stype']=='GEOSEG']
comp_seg_2004_geo[:20]
# Out:
#       gvkey   fyear  total_sales   sid   stype             snms    emps  \
# 79   001021  2004.0       19.833   1.0  GEOSEG    United States     NaN
# 104  001034  2004.0     1339.480  11.0  GEOSEG            Other     NaN
# 105  001034  2004.0     1339.480   8.0  GEOSEG           Norway     NaN
# 107  001034  2004.0     1339.480   1.0  GEOSEG    United States     NaN
# 110  001034  2004.0     1339.480   9.0  GEOSEG          Denmark     NaN
# 155  001045  2004.0    18645.000   7.0  GEOSEG    Latin America     NaN
# 156  001045  2004.0    18645.000   2.0  GEOSEG    United States     NaN
# 157  001045  2004.0    18645.000   8.0  GEOSEG          Pacific     NaN
# 158  001045  2004.0    18645.000   5.0  GEOSEG           Europe     NaN
# 211  001056  2004.0      414.101   2.0  GEOSEG    United States  2398.0
# 266  001075  2004.0     2899.725   2.0  GEOSEG    United States  7200.0
# 439  001097  2004.0       30.836   2.0  GEOSEG    United States     NaN
# 468  001104  2004.0       43.381   3.0  GEOSEG           Canada     NaN
# 469  001104  2004.0       43.381   1.0  GEOSEG    United States     NaN
# 503  001109  2004.0        9.109   2.0  GEOSEG    United States    31.0
# 533  001117  2004.0       20.656   2.0  GEOSEG    United States    76.0
# 557  001121  2004.0     2069.788   2.0  GEOSEG    United States   672.0
# 603  001161  2004.0     5001.435  16.0  GEOSEG            China     NaN
# 604  001161  2004.0     5001.435  15.0  GEOSEG  Other Countries     NaN
# 607  001161  2004.0     5001.435  10.0  GEOSEG           Europe     NaN
#
#       seg_sale SICS1  sic2d  SICGRP
# 79      19.833  3861     38   MANUF
# 104    102.029  2834     28   MANUF
# 105     18.600  2834     28   MANUF
# 107    368.400  2834     28   MANUF
# 110     24.300  2834     28   MANUF
# 155   3115.000  4512     45  TR-UTL
# 156  12192.000  4512     45  TR-UTL
# 157    660.000  4512     45  TR-UTL
# 158   2678.000  4512     45  TR-UTL
# 211    414.101  3825     38   MANUF
# 266   2899.725  4911     49  TR-UTL
# 439     30.836  6331     63  F-I-RE
# 468      5.986  3421     34   MANUF
# 469     32.511  3421     34   MANUF
# 503      9.109  3944     39   MANUF
# 533     20.656  3663     36   MANUF
# 557   2069.788  5172     51  WHL-RT
# 603    464.373  3674     36   MANUF
# 604    934.930  3674     36   MANUF
# 607   1312.613  3674     36   MANUF

# %%
hh_site_2004_geo = hh_site_2004[hh_site_2004['gvkey'].isin(comp_seg_2004_geo.gvkey.tolist())]
hh_site_2004_geo[:20]
# Out:
#      gvkey    year  corpid     siteid  emple  reven  avg_reven  \
# 13  001021  2004.0    5278  147007555     60      8   0.133333
# 14  001021  2004.0    5278  121024812     35      3   0.085714
# 15  001021  2004.0    5278  147002506      4      1   0.250000
# 16  001021  2004.0    5278  133015300    200     44   0.220000
# 17  001075  2004.0    3050  103005467   1000    256   0.256000
# 18  001075  2004.0    3050  111012308    100     10   0.100000
# 19  001075  2004.0    3050  103015808     15      1   0.066667
# 20  001075  2004.0    3050  103027250     19      5   0.263158
# 21  001075  2004.0    3050  103006061    250     64   0.256000
# 22  001075  2004.0    3050  103005957     70      9   0.128571
# 23  001075  2004.0    3050  103003205    100     36   0.360000
# 24  001075  2004.0    3050  103006265   1200    307   0.255833
# 25  001075  2004.0    3050  132001221    563    200   0.355240
# 26  001075  2004.0    3050  103014208     70      4   0.057143
# 67  001104  2004.0    6922  134003032     40      6   0.150000
# 68  001104  2004.0    6922  107007800     15      2   0.133333
# 71  001121  2004.0    1335  144000949    250    270   1.080000
# 73  001161  2004.0    1059  105003783   4000    904   0.226000
# 74  001173  2004.0    5452  147000113    120     19   0.158333
# 75  001173  2004.0    5452  117012914     12      2   0.166667
#
#             corphdq  siccode  SICGRP  entrevenue
# 13  BRANCH               781  AG-M-C          24
# 14  BRANCH              8661  SVCS            24
# 15  BRANCH              3861  MANUF           24
# 16  ULTIMATE HQ         3843  MANUF           24
# 17  ULTIMATE HQ         4911  TR-UTL        2834
# 18  BRANCH              8999  SVCS          2834
# 19  BRANCH              7011  SVCS          2834
# 20  BRANCH              4911  TR-UTL        2834
# 21  BRANCH              4911  TR-UTL        2834
# 22  DIVISIONAL HQ       6552  F-I-RE        2834
# 23  BRANCH              6719  F-I-RE        2834
# 24  BRANCH              4911  TR-UTL        2834
# 25  BRANCH              4911  TR-UTL        2834
# 26  BRANCH              7997  SVCS          2834
# 67  BRANCH              3841  MANUF           34
# 68  ULTIMATE HQ         3914  MANUF           34
# 71  ULTIMATE HQ         5172  WHL-RT        1722
# 73  ULTIMATE HQ         3674  MANUF         3519
# 74  BRANCH              3812  MANUF           27
# 75  BRANCH              3728  MANUF           27

# %%
comp_seg_2004_st = comp_seg_2004[comp_seg_2004['stype']=='STSEG']
comp_seg_2004_st[:50]
# Out:
#         gvkey   fyear  total_sales   sid  stype  \
# 45343  012125  2004.0          NaN   4.0  STSEG
# 45344  012125  2004.0          NaN  12.0  STSEG
# 45345  012125  2004.0          NaN   5.0  STSEG
# 45346  012125  2004.0          NaN  11.0  STSEG
# 51525  013562  2004.0          NaN  11.0  STSEG
# 51526  013562  2004.0          NaN  10.0  STSEG
# 51527  013562  2004.0          NaN   9.0  STSEG
# 51528  013562  2004.0          NaN   8.0  STSEG
# 51529  013562  2004.0          NaN   7.0  STSEG
# 51530  013562  2004.0          NaN   5.0  STSEG
# 55400  014790  2004.0     2040.004  13.0  STSEG
# 55401  014790  2004.0     2040.004  12.0  STSEG
# 55402  014790  2004.0     2040.004  11.0  STSEG
# 56327  015123  2004.0          NaN  27.0  STSEG
# 56328  015123  2004.0          NaN  26.0  STSEG
# 56329  015123  2004.0          NaN  25.0  STSEG
# 56330  015123  2004.0          NaN  24.0  STSEG
# 56331  015123  2004.0          NaN  23.0  STSEG
# 56332  015123  2004.0          NaN  22.0  STSEG
# 56333  015123  2004.0          NaN  21.0  STSEG
# 56334  015123  2004.0          NaN  20.0  STSEG
# 56335  015123  2004.0          NaN  19.0  STSEG
# 61403  020021  2004.0      816.227   6.0  STSEG
# 61404  020021  2004.0      816.227   5.0  STSEG
# 61406  020021  2004.0      816.227   3.0  STSEG
# 61407  020021  2004.0      816.227   4.0  STSEG
# 61408  020021  2004.0      816.227   2.0  STSEG
# 67003  024232  2004.0          NaN   4.0  STSEG
# 67004  024232  2004.0          NaN   3.0  STSEG
# 67005  024232  2004.0          NaN   2.0  STSEG
# 68910  024825  2004.0          NaN   9.0  STSEG
# 68911  024825  2004.0          NaN   8.0  STSEG
# 68912  024825  2004.0          NaN   7.0  STSEG
# 68913  024825  2004.0          NaN   6.0  STSEG
# 68914  024825  2004.0          NaN   5.0  STSEG
# 68915  024825  2004.0          NaN   4.0  STSEG
# 68916  024825  2004.0          NaN   3.0  STSEG
# 80534  029492  2004.0          NaN   4.0  STSEG
# 80536  029492  2004.0          NaN   5.0  STSEG
# 80537  029492  2004.0          NaN   3.0  STSEG
# 83330  030293  2004.0          NaN   6.0  STSEG
# 83331  030293  2004.0          NaN   5.0  STSEG
# 83332  030293  2004.0          NaN   4.0  STSEG
# 83333  030293  2004.0          NaN   3.0  STSEG
# 83334  030293  2004.0          NaN   2.0  STSEG
# 92635  061941  2004.0          NaN  29.0  STSEG
# 92636  061941  2004.0          NaN  28.0  STSEG
# 92637  061941  2004.0          NaN  27.0  STSEG
# 92638  061941  2004.0          NaN  26.0  STSEG
# 92639  061941  2004.0          NaN  19.0  STSEG
#
#                                                     snms  emps  seg_sale  \
# 45343                                Southern California   NaN    15.873
# 45344                                            Arizona   NaN    18.614
# 45345                                          Northwest   NaN     9.655
# 45346                                           Colorado   NaN    13.924
# 51525                                          Corporate   NaN     7.626
# 51526                                              Urban   NaN    26.319
# 51527                               Pennsylvania - North   NaN    73.882
# 51528                                Pennsylvania - West   NaN    87.535
# 51529                                         New Jersey   NaN    94.096
# 51530                                           Virginia   NaN    27.099
# 55400                                               East   NaN     0.000
# 55401                                            Central   NaN  1270.919
# 55402                                               West   NaN   769.085
# 56327                                Corporate and Other   NaN    31.574
# 56328              Office Properties - Secondary Markets   NaN   131.188
# 56329                Office Properties - Washington D.C.   NaN   118.926
# 56330                       Office Properties - New York   NaN   217.761
# 56331                    Office Properties - Los Angeles   NaN    72.217
# 56332                        Office Properties - Houston   NaN   122.387
# 56333                         Office Properties - Dallas   NaN    88.304
# 56334                        Office Properties - Chicago   NaN    75.137
# 56335                        Office Properties - Atlanta   NaN    88.532
# 61403                        Casino Aztar Caruthersville   NaN    23.584
# 61404                            Casino Aztar Evansville   NaN   130.699
# 61406                                Tropicana Las Vegas   NaN   163.954
# 61407                            Ramada Express Laughlin   NaN    93.276
# 61408                            Tropicana Atlantic City   NaN   404.714
# 67003                                              Other   NaN    33.585
# 67004                                            Florida   NaN     2.548
# 67005                                          Louisiana   NaN    72.733
# 68910                   St Mary's & King George Counties   NaN     5.483
# 68911                                  Suburban Maryland   NaN     8.924
# 68912                                  Northern Virginia   NaN    48.701
# 68913                                 Greater Harrisburg   NaN     8.855
# 68914                                              Other   NaN     7.847
# 68915                        Northern/Central New Jersey   NaN    18.793
# 68916                               Greater Philadelphia   NaN    10.025
# 80534                Property & Casualty - Massachusetts   NaN  1565.990
# 80536  Property & Casualty Insurance-Other Than Massa...   NaN   240.338
# 80537                                  Corporate & Other   NaN    -0.488
# 83330                                        Other areas   NaN    13.640
# 83331                                        Non-Segment   NaN     0.000
# 83332                                  Pacific Northwest   NaN    43.326
# 83333                                Southern California   NaN   158.876
# 83334                                Northern California   NaN    58.328
# 92635                                         All Others   NaN    14.038
# 92636                                          Las Vegas   NaN     5.041
# 92637                                      San Francisco   NaN    10.177
# 92638                                Southern California   NaN    33.514
# 92639                                             Denver   NaN     5.585
#
#       SICS1  sic2d  SICGRP
# 45343  6798     67  F-I-RE
# 45344  6798     67  F-I-RE
# 45345  6798     67  F-I-RE
# 45346  6798     67  F-I-RE
# 51525  6798     67  F-I-RE
# 51526  6798     67  F-I-RE
# 51527  6798     67  F-I-RE
# 51528  6798     67  F-I-RE
# 51529  6798     67  F-I-RE
# 51530  6798     67  F-I-RE
# 55400  1531     15  AG-M-C
# 55401  1531     15  AG-M-C
# 55402  1531     15  AG-M-C
# 56327  6798     67  F-I-RE
# 56328  6798     67  F-I-RE
# 56329  6798     67  F-I-RE
# 56330  6798     67  F-I-RE
# 56331  6798     67  F-I-RE
# 56332  6798     67  F-I-RE
# 56333  6798     67  F-I-RE
# 56334  6798     67  F-I-RE
# 56335  6798     67  F-I-RE
# 61403  7999     79    SVCS
# 61404  7999     79    SVCS
# 61406  7999     79    SVCS
# 61407  7999     79    SVCS
# 61408  7999     79    SVCS
# 67003  6162     61  F-I-RE
# 67004  6021     60  F-I-RE
# 67005  6021     60  F-I-RE
# 68910  6798     67  F-I-RE
# 68911  6798     67  F-I-RE
# 68912  6798     67  F-I-RE
# 68913  6798     67  F-I-RE
# 68914  6798     67  F-I-RE
# 68915  6798     67  F-I-RE
# 68916  6798     67  F-I-RE
# 80534  6331     63  F-I-RE
# 80536  6331     63  F-I-RE
# 80537  6799     67  F-I-RE
# 83330  6798     67  F-I-RE
# 83331  6798     67  F-I-RE
# 83332  6798     67  F-I-RE
# 83333  6798     67  F-I-RE
# 83334  6798     67  F-I-RE
# 92635  6798     67  F-I-RE
# 92636  6798     67  F-I-RE
# 92637  6798     67  F-I-RE
# 92638  6798     67  F-I-RE
# 92639  6798     67  F-I-RE

# %%
hh_site_2004_st = hh_site_2004[hh_site_2004['gvkey'].isin(comp_seg_2004_st.gvkey.tolist())]
hh_site_2004_st[:20]
# Out:
#         gvkey    year  corpid     siteid  emple  reven  avg_reven  \
# 38525  014790  2004.0     734  103006159     25     17   0.680000
# 38526  014790  2004.0     734  103031232     25     17   0.680000
# 38527  014790  2004.0     734  144024497     60     30   0.500000
# 42095  020021  2004.0    6872  115008923   1200     54   0.045000
# 42096  020021  2004.0    6872  103006289     21      1   0.047619
# 42097  020021  2004.0    6872  129000838   2500    185   0.074000
# 42098  020021  2004.0    6872  126006045    325     20   0.061538
# 42099  020021  2004.0    6872  129001722   1450    107   0.073793
# 42100  020021  2004.0    6872  131005029   5000    460   0.092000
# 47826  030293  2004.0    5577  105030518     60     27   0.450000
# 47827  030293  2004.0    5577  105123639     13      3   0.230769
# 47828  030293  2004.0    5577  148009026     12      3   0.250000
# 47829  030293  2004.0    5577  105168164     17      4   0.235294
# 47830  030293  2004.0    5577  105124917     10      2   0.200000
# 47831  030293  2004.0    5577  105045489     10      2   0.200000
# 50269  061941  2004.0   38375  105008428    100     25   0.250000
# 52331  064925  2004.0   48859  122033700     15      5   0.333333
# 52332  064925  2004.0   48859  133059019     25      7   0.280000
# 52333  064925  2004.0   48859  122009755    250     90   0.360000
# 52334  064925  2004.0   48859  133058142     25      7   0.280000
#
#                corphdq  siccode  SICGRP  entrevenue
# 38525  NOT LINKED          1521  AG-M-C          17
# 38526  ULTIMATE HQ         1521  AG-M-C        1471
# 38527  DIVISIONAL HQ       1542  AG-M-C        1471
# 42095  BRANCH              7011  SVCS           834
# 42096  ULTIMATE HQ         7999  SVCS           834
# 42097  BRANCH              7011  SVCS           834
# 42098  BRANCH              7993  SVCS           834
# 42099  BRANCH              7011  SVCS           834
# 42100  BRANCH              7011  SVCS           834
# 47826  ULTIMATE HQ         6798  F-I-RE         234
# 47827  BRANCH              6513  F-I-RE         234
# 47828  BRANCH              6513  F-I-RE         234
# 47829  BRANCH              6513  F-I-RE         234
# 47830  BRANCH              6513  F-I-RE         234
# 47831  BRANCH              6513  F-I-RE         234
# 50269  ULTIMATE HQ         6531  F-I-RE         185
# 52331  BRANCH              6531  F-I-RE        1309
# 52332  BRANCH              6531  F-I-RE        1309
# 52333  ULTIMATE HQ         6552  F-I-RE        1309
# 52334  BRANCH              6531  F-I-RE        1309

# %%
temp1 = comp_seg_2004[comp_seg_2004['gvkey']=='001004']
temp2 = hh_site_2004[hh_site_2004['gvkey']=='001004']

# %%
temp1.sort_values('SICGRP')
# Out:
#      gvkey   fyear  total_sales   sid   stype  \
# 15  001004  2004.0      747.848  16.0  BUSSEG
# 14  001004  2004.0      747.848  18.0  BUSSEG
# 12  001004  2004.0      747.848  15.0  BUSSEG
# 13  001004  2004.0      747.848  17.0  BUSSEG
#
#                                 snms  emps  seg_sale SICS1  sic2d  SICGRP
# 15            Structures and Systems   NaN   193.296  3559     35   MANUF
# 14  Maintenance, Repair and Overhaul   NaN   111.932  4581     45  TR-UTL
# 12             Aviation Supply Chain   NaN   390.060  5088     50  WHL-RT
# 13        Aircraft Sales and Leasing   NaN    45.139  5088     50  WHL-RT

# %%
temp2.sort_values('SICGRP')
# Out:
#     gvkey    year  corpid     siteid  emple  reven  avg_reven  \
# 1  001004  2004.0    5689  110023187    130     18   0.138462
# 4  001004  2004.0    5689  123000762    105     49   0.466667
# 7  001004  2004.0    5689  107007880     60     11   0.183333
# 8  001004  2004.0    5689  123009340    450     39   0.086667
# 3  001004  2004.0    5689  133034746     70      9   0.128571
# 6  001004  2004.0    5689  133018882    170     22   0.129412
# 0  001004  2004.0    5689  133011193     60     11   0.183333
# 2  001004  2004.0    5689  110018783    200     42   0.210000
# 5  001004  2004.0    5689  114001316    350    301   0.860000
#
#            corphdq  siccode  SICGRP  entrevenue
# 1  BRANCH              3728  MANUF          854
# 4  BRANCH              3728  MANUF          854
# 7  BRANCH              3511  MANUF          854
# 8  BRANCH              2448  MANUF          854
# 3  BRANCH              7699  SVCS           854
# 6  BRANCH              7699  SVCS           854
# 0  BRANCH              4581  TR-UTL         854
# 2  BRANCH              4581  TR-UTL         854
# 5  ULTIMATE HQ         5063  WHL-RT         854

# %%
temp1.groupby('SICGRP').agg({"seg_sale": 'sum'})
# Out:
#         seg_sale
# SICGRP
# MANUF    193.296
# TR-UTL   111.932
# WHL-RT   435.199

# %%
temp2.groupby('SICGRP').agg({"reven": 'sum'})
# Out:
#         reven
# SICGRP
# MANUF     117
# SVCS       31
# TR-UTL     53
# WHL-RT    301
